# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\HP\Downloads\mlproject\notebook\stud.csv")

#data.info()
#data.info()

# %%
#data.isnull().sum()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#define numerical and catgorical columns
numeric_features=[feature for feature in data.columns if data[feature].dtype != '0' ]
catgorical_features=[feature for feature in data.columns if data[feature].dtype=='0']

print('we have numerical features :{}'.format(len(numeric_features),numeric_features))
print('\n we have catgoorical feature :{}'.format(len(catgorical_features),catgorical_features))
# Out:
# we have numerical features :8
#
#  we have catgoorical feature :0

# %%
#adding column for total_score and average
data['total_score']=data['math_score']+data['reading_score']+data['writing_score']
#print(data['total_score'])
data['average']=data['total_score']/3
#print(data['average'])
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average, Length: 1000, dtype: float64

# %%
reading_full=data[data['reading_score']==100]['average'].count()
writing_full=data[data['writing_score']==100]['average'].count()
math_full=data[data['math_score']==100]['average'].count()

print(f'number of students with full marks in maths :',(math_full))
print(f'number of students with full marks in writing :',(writing_full))
print(f'number of students with full marks in reading : ',(reading_full))
# Out:
# number of students with full marks in maths : 7
# number of students with ful marks in writing : 14
# number of students with full marks in reading :  17

# %%
reading_less_20=data[data['reading_score']<=20]['average'].count()
writing_less_20=data[data['writing_score']<=20]['average'].count()
math_less_20=data[data['math_score']<=20]['average'].count()

print(f'number of students with less than 20 marks in maths :',(math_less_20))
print(f'number of students with less than 20 in writing :',(writing_less_20))
print(f'number of students with less than 20 in reading : ',(reading_less_20))
# Out:
# number of students with less than 20 marks in maths : 4
# number of students with less than 20 in writing : 3
# number of students with less than 20 in reading :  1

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7)) 
sns.histplot(data=data, x='average', bins=20, kde=True, color='g', ax=axs[0])
sns.histplot(data=data, x='average', bins=30, kde=True,hue='gender', color='r', ax=axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7)) 
sns.histplot(data=data, x='total_score', bins=20, kde=True, color='g', ax=axs[0])
sns.histplot(data=data, x='total_score', bins=30, kde=True,hue='gender', color='r', ax=axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 7)) 
sns.histplot(data=data, x='average', bins=20, kde=True,hue='lunch', color='g', ax=axs[0])
sns.histplot(data=data[data['gender']=='male'], x='average', bins=30, kde=True,hue='lunch', color='r', ax=axs[1])
sns.histplot(data=data[data['gender']=='female'], x='average', bins=30, kde=True,hue='lunch', color='r', ax=axs[2])
plt.show()
